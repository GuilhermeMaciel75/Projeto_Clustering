# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeMaciel75/Projeto_Clustering/blob/main/BDSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-learn-extra
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp39-cp39-manylinux2010_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/dist-packages (from scikit-learn-extra) (1.22.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn-extra) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn-extra) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.1.0)
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors 
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids
from sklearn.metrics.cluster import silhouette_samples, silhouette_score

# %%
def dbs_full(eps_inicial, eps_final, acrescento):
  lista_eps = np.arange(eps_inicial, eps_final + acrescento, acrescento).tolist()

  for eps in lista_eps:
      # Criando uma instância do modelo DBSCAN com os parametros selecionados
      dbscan = DBSCAN(eps=eps, min_samples=5)

      # Ajustando o modelo aos dados
      dbscan.fit(df_pca)

      # Guardando as etiquetas de classe atribuídas a cada amostra
      labels = dbscan.labels_

      # Definindo e imprimindo o número de clusters e o número de amostras de ruído
      n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
      n_noise = list(labels).count(-1)
      print('eps:', eps)
      print('Número de clusters:', n_clusters)
      print('Número de amostras de ruído:', n_noise)

      # Criando uma figura 3D
      fig = plt.figure(figsize = (8, 8))
      ax = fig.add_subplot(111, projection='3d')

      # Plotando os dados em um gráfico de dispersão 3D
      ax.scatter(df_pca[0], df_pca[1], df_pca[2], c=labels, cmap='viridis')

      # Definindo rótulos de eixo e título do gráfico
      ax.set_xlabel('Recurso 1')
      ax.set_ylabel('Recurso 2')
      ax.set_zlabel('Recurso 3')
      ax.set_title('Resultado do DBSCAN em 3D')

      # Exibindo gráfico
      plt.show()

# %% [markdown]
# ## Ajustando dataset

# %%
# Carregando o conjunto de dados
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data"
df = pd.read_csv(url, header=None)

# Obtendo os rótulos de classe
targets = df[0]

# Descartando a coluna de rótulo
df = df.drop(columns=[0])

# Convertendo o dataframe para uma matriz NumPy e atribui o tipo float aos dados
data = df.values
X = data.astype(float)

# %% [markdown]
# ## Normalizando dataset e aplicando PCA

# %%
# Normalizando os recursos usando o método Z-score
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# Converter os recursos normalizados de volta para DataFrame
df_normalized = pd.DataFrame(X)

# Criando uma instância do modelo PCA com três componentes
pca = PCA(n_components=3)

# Ajustando o modelo aos dados
X_pca = pca.fit_transform(X)

# Tranformando o modelo de dados PCA em um dataframe em pandas
df_pca = pd.DataFrame(X_pca)

# %% [markdown]
# ## Usando o método Elbow para encontrar o valor ideal de clusteres

# %% [markdown]
# **Ele já retorna o melhor valor para o cluster, como pode ser visto no gráfico abaixo, o melhor valor para K é o 3**

# %%
model = KMedoids()
visualizer = KElbowVisualizer(model, k=(1,20))
visualizer.fit(df_normalized) 
visualizer.poof()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMedoids Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ## Encontrando o número ideal de eps
# ### Calculando a distância entre um ponto e seus vizinhos usando o método NearestNeighbors

# %%
# Criando uma instância da classe NearestNeighbors 
# (encontra os dois vizinhos mais próximos de cada ponto no conjunto de dados)
neigh = NearestNeighbors(n_neighbors=2)

# # Ajustando o modelo ao conjunto de dados
nbrs = neigh.fit(df_pca)

# Aplicação do modelo treinado na base de dados df_pca, utilizando o método kneighbors()
# (encontra as distâncias e os índices dos dois vizinhos mais próximos de cada ponto em df_pca).
distances, indices = nbrs.kneighbors(df_pca)

# %%
# Ordenando as distancias
distances = np.sort(distances, axis=0)
distances = distances[:,1]

# Plotando o resultado
plt.plot(distances)

# %% [markdown]
# O ponto de curvatura máxima esta entre 0.7 a 1

# %% [markdown]
# Como encontramos que o valor ideal de eps esta entre 0.7 e 1.0

# %% [markdown]
# ## Aplicando DBSCAN e encontrando o número de clusters e ruídos

# %%
dbs_full(0.7, 1, 0.05)
# Out:
# eps: 0.7
# Número de clusters: 6
# Número de amostras de ruído: 85
# eps: 0.75
# Número de clusters: 5
# Número de amostras de ruído: 73
# eps: 0.8
# Número de clusters: 3
# Número de amostras de ruído: 65
# eps: 0.8500000000000001
# Número de clusters: 3
# Número de amostras de ruído: 45
# eps: 0.9000000000000001
# Número de clusters: 2
# Número de amostras de ruído: 30
# eps: 0.9500000000000002
# Número de clusters: 2
# Número de amostras de ruído: 27
# eps: 1.0000000000000002
# Número de clusters: 2
# Número de amostras de ruído: 25
# eps: 1.0500000000000003
# Número de clusters: 1
# Número de amostras de ruído: 16

# %% [markdown]
# Analisando os resultados, o número ideal de eps está entre 0.8 e 0.9, já que o número de clusteres é igual a 3 e o número de ruídos está reduzindo, porém, podemos analisar ainda mais precisamente:

# %%
dbs_full(0.8, 0.9, 0.01)
# Out:
# eps: 0.8
# Número de clusters: 3
# Número de amostras de ruído: 65
# eps: 0.81
# Número de clusters: 3
# Número de amostras de ruído: 64
# eps: 0.8200000000000001
# Número de clusters: 3
# Número de amostras de ruído: 62
# eps: 0.8300000000000001
# Número de clusters: 4
# Número de amostras de ruído: 52
# eps: 0.8400000000000001
# Número de clusters: 3
# Número de amostras de ruído: 49
# eps: 0.8500000000000001
# Número de clusters: 3
# Número de amostras de ruído: 45
# eps: 0.8600000000000001
# Número de clusters: 2
# Número de amostras de ruído: 38
# eps: 0.8700000000000001
# Número de clusters: 2
# Número de amostras de ruído: 37
# eps: 0.8800000000000001
# Número de clusters: 2
# Número de amostras de ruído: 35
# eps: 0.8900000000000001
# Número de clusters: 2
# Número de amostras de ruído: 34
# eps: 0.9000000000000001
# Número de clusters: 2
# Número de amostras de ruído: 30

# %% [markdown]
# ### O número ideal de eps escolhido foi de 0.85, já que mais precisamente entre 0.85 e 0.86
